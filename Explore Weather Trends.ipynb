# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Import data from csv
temp_data = pd.read_csv('C:\\Users\\Alex\\Desktop\\Miya\\Explore Weather Trends\\combined-data.csv')
temp_data.head()
# Out:
#    year         city        country  city_avg_temp  global_avg_temp
# 0  1849  Los Angeles  United States          15.71             7.98
# 1  1850  Los Angeles  United States          15.28             7.90
# 2  1851  Los Angeles  United States          15.53             8.18
# 3  1852  Los Angeles  United States          15.61             8.10
# 4  1853  Los Angeles  United States          16.27             8.04

# %%
avg_temp = temp_data[['city_avg_temp', 'global_avg_temp']]
print(avg_temp.describe())
# Out:
#        city_avg_temp  global_avg_temp
# count     165.000000       165.000000
# mean       15.881152         8.554545
# std         0.568754         0.460165
# min        14.360000         7.560000
# 25%        15.500000         8.190000
# 50%        15.800000         8.530000
# 75%        16.240000         8.770000
# max        18.120000         9.730000

# %%
#Data
temp_data['la_ma']=temp_data['city_avg_temp'].rolling(window=10).mean()
temp_data['global_ma']=temp_data['global_avg_temp'].rolling(window=10).mean()
temp_data.tail()
# Out:
#      year         city        country  city_avg_temp  global_avg_temp   la_ma  \
# 160  2009  Los Angeles  United States          16.68             9.51  16.647
# 161  2010  Los Angeles  United States          15.89             9.70  16.572
# 162  2011  Los Angeles  United States          15.87             9.52  16.512
# 163  2012  Los Angeles  United States          17.09             9.51  16.578
# 164  2013  Los Angeles  United States          18.12             9.61  16.696
#
#      global_ma
# 160      9.493
# 161      9.543
# 162      9.554
# 163      9.548
# 164      9.556

# %%
#Local moving average of temp vs. year
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10,4))
temp_data.plot(kind='line', x='year', y='la_ma', ax=ax)
ax.set(title='Los Angeles Temperature Trends', xlabel='Year', ylabel='Celcius', ylim=(15,17))
ax.grid(True)

# %%
#Global moving average of temp vs. year
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10,4))
temp_data.plot(kind='line', x='year', y='global_ma', ax=ax)
ax.set(title='Global Temperature Trends', xlabel='Year', ylabel='Celcius', ylim=(7.5,10))
ax.grid(True)

# %%
#Los Angeles vs. Global moving average of temp 
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(10,4))
temp_data.plot(kind='line', x='year', y=['la_ma','global_ma'], ax=ax)
ax.set(title='Global vs. Los Angeles Temperature Trends', xlabel='Year', ylabel='Celcius', ylim=(5,20))
ax.grid(True)
